# %%
import pandas as pd
import sys
sys.path.append('../')

# %%
# !pwd
# Out:
# /Users/danielaarias/Ironhack/Semana_06/API_Flask/Notebooks

# %%
df = pd.read_csv('../Data/tbb.csv')

# %%
df.head()
# Out:
#                            episode_name  \
# 0  Series 01 Episode 01 – Pilot Episode
# 1  Series 01 Episode 01 – Pilot Episode
# 2  Series 01 Episode 01 – Pilot Episode
# 3  Series 01 Episode 01 – Pilot Episode
# 4  Series 01 Episode 01 – Pilot Episode
#
#                                             dialogue person_scene
# 0                        A corridor at a sperm bank.        Scene
# 1   So if a photon is directed through a plane wi...      Sheldon
# 2                         Agreed, what’s your point?      Leonard
# 3   There’s no point, I just think it’s a good id...      Sheldon
# 4                                         Excuse me?      Leonard

# %% [markdown]
# ## Voy a quedarme con los personajes principales de la serie

# %%
y = df["person_scene"].value_counts()

# %%
for i in y:
    if i > 3000:
        print(i)
# Out:
# 11484
# 9638
# 7477
# 5737
# 4576
# 3419

# %%
y[0:6]
# Out:
# Sheldon    11484
# Leonard     9638
# Penny       7477
# Howard      5737
# Raj         4576
# Amy         3419
# Name: person_scene, dtype: int64

# %%
df3 = df[((df.person_scene=="Sheldon")|(df.person_scene=="Leonard")|(df.person_scene=="Penny")|(df.person_scene=="Howard")|(df.person_scene=="Amy"))]

# %%
df3.reset_index(drop=True)
# Out:
#                                             episode_name  \
# 0                   Series 01 Episode 01 – Pilot Episode
# 1                   Series 01 Episode 01 – Pilot Episode
# 2                   Series 01 Episode 01 – Pilot Episode
# 3                   Series 01 Episode 01 – Pilot Episode
# 4                   Series 01 Episode 01 – Pilot Episode
# ...                                                  ...
# 37750  Series 10 Episode 24 – The Long Distance Disso...
# 37751  Series 10 Episode 24 – The Long Distance Disso...
# 37752  Series 10 Episode 24 – The Long Distance Disso...
# 37753  Series 10 Episode 24 – The Long Distance Disso...
# 37754  Series 10 Episode 24 – The Long Distance Disso...
#
#                                                 dialogue person_scene
# 0       So if a photon is directed through a plane wi...      Sheldon
# 1                             Agreed, what’s your point?      Leonard
# ...

# %%
#df2 = [df2["person_scene"].drop([i], axis=0, inplace=True) if i != ['Sheldon'|'Leonard'|'Penny'|'Howard'|'Amy'] for i in df2["person_scene"]]

# %%
#for i in df2["person_scene"]:
    #if i != ['Sheldon' or 'Leonard' or 'Penny' or 'Howard' or 'Amy']:
        #df2["person_scene"].drop([i], axis=0, inplace=True)

# %% [markdown]
# ## Columna Episode

# %%
df3.head()
# Out:
#                            episode_name  \
# 1  Series 01 Episode 01 – Pilot Episode
# 2  Series 01 Episode 01 – Pilot Episode
# 3  Series 01 Episode 01 – Pilot Episode
# 4  Series 01 Episode 01 – Pilot Episode
# 6  Series 01 Episode 01 – Pilot Episode
#
#                                             dialogue person_scene
# 1   So if a photon is directed through a plane wi...      Sheldon
# 2                         Agreed, what’s your point?      Leonard
# 3   There’s no point, I just think it’s a good id...      Sheldon
# 4                                         Excuse me?      Leonard
# 6   One across is Aegean, eight down is Nabakov, ...      Leonard

# %%
df3[['col1', 'Name_episode']] = df3['episode_name'].str.split(" – ", expand = True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df3.head()
# Out:
#                            episode_name  \
# 1  Series 01 Episode 01 – Pilot Episode
# 2  Series 01 Episode 01 – Pilot Episode
# 3  Series 01 Episode 01 – Pilot Episode
# 4  Series 01 Episode 01 – Pilot Episode
# 6  Series 01 Episode 01 – Pilot Episode
#
#                                             dialogue person_scene  \
# 1   So if a photon is directed through a plane wi...      Sheldon
# 2                         Agreed, what’s your point?      Leonard
# 3   There’s no point, I just think it’s a good id...      Sheldon
# 4                                         Excuse me?      Leonard
# 6   One across is Aegean, eight down is Nabakov, ...      Leonard
#
#                    col1   Name_episode
# 1  Series 01 Episode 01  Pilot Episode
# 2  Series 01 Episode 01  Pilot Episode
# 3  Series 01 Episode 01  Pilot Episode
# 4  Series 01 Episode 01  Pilot Episode
# 6  Series 01 Episode 01  Pilot Episode

# %%
df3[['col3', 'Number_Series', 'col5', 'Number_Episode', 'col7', 'col8']] = df3['col1'].str.split(" ", expand = True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df3
# Out:
#                                             episode_name  \
# 1                   Series 01 Episode 01 – Pilot Episode
# 2                   Series 01 Episode 01 – Pilot Episode
# 3                   Series 01 Episode 01 – Pilot Episode
# 4                   Series 01 Episode 01 – Pilot Episode
# 6                   Series 01 Episode 01 – Pilot Episode
# ...                                                  ...
# 54397  Series 10 Episode 24 – The Long Distance Disso...
# 54399  Series 10 Episode 24 – The Long Distance Disso...
# 54401  Series 10 Episode 24 – The Long Distance Disso...
# 54403  Series 10 Episode 24 – The Long Distance Disso...
# 54405  Series 10 Episode 24 – The Long Distance Disso...
#
#                                                 dialogue person_scene  \
# 1       So if a photon is directed through a plane wi...      Sheldon
# 2                             Agreed, what’s your point?      Leonard
# ...

# %%
renombrar = {"dialogue": "Dialogue", "person_scene":"Actor","Name_episode": "Name_Episode" }

# %%
df3.rename(columns = renombrar, inplace=True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df3.head()
# Out:
#                            episode_name  \
# 1  Series 01 Episode 01 – Pilot Episode
# 2  Series 01 Episode 01 – Pilot Episode
# 3  Series 01 Episode 01 – Pilot Episode
# 4  Series 01 Episode 01 – Pilot Episode
# 6  Series 01 Episode 01 – Pilot Episode
#
#                                             Dialogue    Actor  \
# 1   So if a photon is directed through a plane wi...  Sheldon
# 2                         Agreed, what’s your point?  Leonard
# 3   There’s no point, I just think it’s a good id...  Sheldon
# 4                                         Excuse me?  Leonard
# 6   One across is Aegean, eight down is Nabakov, ...  Leonard
#
#                    col1   Name_Episode    col3 Number_Series     col5  \
# 1  Series 01 Episode 01  Pilot Episode  Series            01  Episode
# 2  Series 01 Episode 01  Pilot Episode  Series            01  Episode
# 3  Series 01 Episode 01  Pilot Episode  Series            01  Episode
# ...

# %% [markdown]
# ## Nos quedamos con las columnas que utilizaremos en nuestra BBDD

# %%
df3.drop(["episode_name", "col1", "col3","col5","col7","col8"], axis=1, inplace=True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df3.head()
# Out:
#                                             Dialogue    Actor   Name_Episode  \
# 1   So if a photon is directed through a plane wi...  Sheldon  Pilot Episode
# 2                         Agreed, what’s your point?  Leonard  Pilot Episode
# 3   There’s no point, I just think it’s a good id...  Sheldon  Pilot Episode
# 4                                         Excuse me?  Leonard  Pilot Episode
# 6   One across is Aegean, eight down is Nabakov, ...  Leonard  Pilot Episode
#
#   Number_Series Number_Episode
# 1            01             01
# 2            01             01
# 3            01             01
# 4            01             01
# 6            01             01

# %%
df
