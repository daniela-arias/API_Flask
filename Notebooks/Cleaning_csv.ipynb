# %%
import pandas as pd
import sys
sys.path.append('../')

# %%
# !pwd
# Out:
# /Users/danielaarias/Ironhack/Semana_06/API_Flask/Notebooks

# %%
df = pd.read_csv('../Data/tbb.csv')

# %%
df.head()
# Out:
#                            episode_name  \
# 0  Series 01 Episode 01 – Pilot Episode
# 1  Series 01 Episode 01 – Pilot Episode
# 2  Series 01 Episode 01 – Pilot Episode
# 3  Series 01 Episode 01 – Pilot Episode
# 4  Series 01 Episode 01 – Pilot Episode
#
#                                             dialogue person_scene
# 0                        A corridor at a sperm bank.        Scene
# 1   So if a photon is directed through a plane wi...      Sheldon
# 2                         Agreed, what’s your point?      Leonard
# 3   There’s no point, I just think it’s a good id...      Sheldon
# 4                                         Excuse me?      Leonard

# %% [markdown]
# ## Voy a quedarme con los personajes principales de la serie

# %%
y = df["person_scene"].value_counts()

# %%
for i in y:
    if i > 3000:
        print(i)
# Out:
# 11484
# 9638
# 7477
# 5737
# 4576
# 3419

# %%
y[0:6]
# Out:
# Sheldon    11484
# Leonard     9638
# Penny       7477
# Howard      5737
# Raj         4576
# Amy         3419
# Name: person_scene, dtype: int64

# %%
df3 = df[((df.person_scene=="Sheldon")|(df.person_scene=="Leonard")|(df.person_scene=="Penny")|(df.person_scene=="Howard")|(df.person_scene=="Amy"))]

# %%
df3.reset_index(drop=True)
# Out:
#                                             episode_name  \
# 0                   Series 01 Episode 01 – Pilot Episode
# 1                   Series 01 Episode 01 – Pilot Episode
# 2                   Series 01 Episode 01 – Pilot Episode
# 3                   Series 01 Episode 01 – Pilot Episode
# 4                   Series 01 Episode 01 – Pilot Episode
# ...                                                  ...
# 37750  Series 10 Episode 24 – The Long Distance Disso...
# 37751  Series 10 Episode 24 – The Long Distance Disso...
# 37752  Series 10 Episode 24 – The Long Distance Disso...
# 37753  Series 10 Episode 24 – The Long Distance Disso...
# 37754  Series 10 Episode 24 – The Long Distance Disso...
#
#                                                 dialogue person_scene
# 0       So if a photon is directed through a plane wi...      Sheldon
# 1                             Agreed, what’s your point?      Leonard
# ...

# %% [markdown]
# ## Columna Episode

# %%
df3.head()
# Out:
#                            episode_name  \
# 1  Series 01 Episode 01 – Pilot Episode
# 2  Series 01 Episode 01 – Pilot Episode
# 3  Series 01 Episode 01 – Pilot Episode
# 4  Series 01 Episode 01 – Pilot Episode
# 6  Series 01 Episode 01 – Pilot Episode
#
#                                             dialogue person_scene
# 1   So if a photon is directed through a plane wi...      Sheldon
# 2                         Agreed, what’s your point?      Leonard
# 3   There’s no point, I just think it’s a good id...      Sheldon
# 4                                         Excuse me?      Leonard
# 6   One across is Aegean, eight down is Nabakov, ...      Leonard

# %%
df3[['col1', 'Name_episode']] = df3['episode_name'].str.split(" – ", expand = True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df3.head()
# Out:
#                            episode_name  \
# 1  Series 01 Episode 01 – Pilot Episode
# 2  Series 01 Episode 01 – Pilot Episode
# 3  Series 01 Episode 01 – Pilot Episode
# 4  Series 01 Episode 01 – Pilot Episode
# 6  Series 01 Episode 01 – Pilot Episode
#
#                                             dialogue person_scene  \
# 1   So if a photon is directed through a plane wi...      Sheldon
# 2                         Agreed, what’s your point?      Leonard
# 3   There’s no point, I just think it’s a good id...      Sheldon
# 4                                         Excuse me?      Leonard
# 6   One across is Aegean, eight down is Nabakov, ...      Leonard
#
#                    col1   Name_episode
# 1  Series 01 Episode 01  Pilot Episode
# 2  Series 01 Episode 01  Pilot Episode
# 3  Series 01 Episode 01  Pilot Episode
# 4  Series 01 Episode 01  Pilot Episode
# 6  Series 01 Episode 01  Pilot Episode

# %%
df3[['col3', 'Number_Series', 'col5', 'Number_Episode', 'col7', 'col8']] = df3['col1'].str.split(" ", expand = True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df3
# Out:
#                                             episode_name  \
# 1                   Series 01 Episode 01 – Pilot Episode
# 2                   Series 01 Episode 01 – Pilot Episode
# 3                   Series 01 Episode 01 – Pilot Episode
# 4                   Series 01 Episode 01 – Pilot Episode
# 6                   Series 01 Episode 01 – Pilot Episode
# ...                                                  ...
# 54397  Series 10 Episode 24 – The Long Distance Disso...
# 54399  Series 10 Episode 24 – The Long Distance Disso...
# 54401  Series 10 Episode 24 – The Long Distance Disso...
# 54403  Series 10 Episode 24 – The Long Distance Disso...
# 54405  Series 10 Episode 24 – The Long Distance Disso...
#
#                                                 dialogue person_scene  \
# 1       So if a photon is directed through a plane wi...      Sheldon
# 2                             Agreed, what’s your point?      Leonard
# ...

# %%
renombrar = {"dialogue": "Dialogue", "person_scene":"Actor","Name_episode": "Name_Episode" }

# %%
df3.rename(columns = renombrar, inplace=True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df3.head()
# Out:
#                            episode_name  \
# 1  Series 01 Episode 01 – Pilot Episode
# 2  Series 01 Episode 01 – Pilot Episode
# 3  Series 01 Episode 01 – Pilot Episode
# 4  Series 01 Episode 01 – Pilot Episode
# 6  Series 01 Episode 01 – Pilot Episode
#
#                                             Dialogue    Actor  \
# 1   So if a photon is directed through a plane wi...  Sheldon
# 2                         Agreed, what’s your point?  Leonard
# 3   There’s no point, I just think it’s a good id...  Sheldon
# 4                                         Excuse me?  Leonard
# 6   One across is Aegean, eight down is Nabakov, ...  Leonard
#
#                    col1   Name_Episode    col3 Number_Series     col5  \
# 1  Series 01 Episode 01  Pilot Episode  Series            01  Episode
# 2  Series 01 Episode 01  Pilot Episode  Series            01  Episode
# 3  Series 01 Episode 01  Pilot Episode  Series            01  Episode
# ...

# %% [markdown]
# ## Nos quedamos con las columnas que utilizaremos en nuestra BBDD

# %%
df3.drop(["episode_name", "col1", "col3","col5","col7","col8"], axis=1, inplace=True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/Ironhack/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df3.head()
# Out:
#                                             Dialogue    Actor   Name_Episode  \
# 1   So if a photon is directed through a plane wi...  Sheldon  Pilot Episode
# 2                         Agreed, what’s your point?  Leonard  Pilot Episode
# 3   There’s no point, I just think it’s a good id...  Sheldon  Pilot Episode
# 4                                         Excuse me?  Leonard  Pilot Episode
# 6   One across is Aegean, eight down is Nabakov, ...  Leonard  Pilot Episode
#
#   Number_Series Number_Episode
# 1            01             01
# 2            01             01
# 3            01             01
# 4            01             01
# 6            01             01

# %%
def sustituye(x):
    x = str(x).replace('"', "`")
    x = str(x).replace("'", "`")
    return x

# %%
df3['Dialogue'].apply(sustituye)
# Out:
# 1         So if a photon is directed through a plane wi...
# 2                               Agreed, what’s your point?
# 3         There’s no point, I just think it’s a good id...
# 4                                               Excuse me?
# 6         One across is Aegean, eight down is Nabakov, ...
#                                ...
# 54397     Uh, breakfast yes, lunch no. I did have a cou...
# 54399                           How thoughtful. Thank you.
# 54401     And I with you. Question, are you seeking a r...
# 54403     Well, that would raise a number of problems. ...
# 54405     (Knock, knock, knock) Amy. (Knock, knock, kno...
# Name: Dialogue, Length: 37755, dtype: object

# %%
df3.head()
# Out:
#                                             Dialogue    Actor   Name_Episode  \
# 1   So if a photon is directed through a plane wi...  Sheldon  Pilot Episode
# 2                         Agreed, what’s your point?  Leonard  Pilot Episode
# 3   There’s no point, I just think it’s a good id...  Sheldon  Pilot Episode
# 4                                         Excuse me?  Leonard  Pilot Episode
# 6   One across is Aegean, eight down is Nabakov, ...  Leonard  Pilot Episode
#
#   Number_Series Number_Episode
# 1            01             01
# 2            01             01
# 3            01             01
# 4            01             01
# 6            01             01

# %%
df3.to_csv('../Data/Cleaning_ready.csv')

# %% [markdown]
# ## Nos conectamos con la BBDD creada en MySQLWorkbench

# %%
import sqlalchemy as alch
import os
import dotenv

dotenv.load_dotenv()

passw = os.getenv("pass_sql")
dbName = "tbb"
connectionData = f"mysql+pymysql://root:{passw}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/tbb)

# %% [markdown]
# ## Cargamos los datos a nuestra BBDD de SQL

# %%
def check(que,string):
    """
    Función parametrizada que comprueba en cada tabla si existe el user, artista o canción.
    Devuelve True si existe y False si no
    """
    if que == "Season":
        query = list(engine.execute(f"SELECT Number FROM Season WHERE Number = '{string}'"))
        if len(query) > 0:
            return True
        else:
            return False
        
    elif que == "Episode":
        query = list(engine.execute(f"SELECT Name FROM Episode WHERE Name = '{string}'"))
        if len(query) > 0:
            return True
        else:
            return False
       
    elif que == "Actors":
        query = list(engine.execute(f"SELECT Name FROM Actors WHERE Name = '{string}'"))
        if len(query) > 0:
            return True
        else:
            return False
        
    elif que == "Dialogue":
        query = list(engine.execute(f"SELECT Dialogue FROM Dialogue WHERE Dialogue = '{string}'"))
        if len(query) > 0:
            return True
        else:
            return False

# %%
check("Episode", "Hola")
# Out:
# False

# %%
def insertSeason(string):
    """
    Llama a la función check para comprobar si existe season
    Inserta season si no existe
    """
    if check("Season", string):
        return "Esa temporada ya existe"
    else:
        engine.execute(f"INSERT INTO Season (Number) VALUES ('{string}');")

# %%
def insertEpisode(nombre, number):
    """
    Llama a la función check para comprobar si existe el Episode
    Inserta episode si no existe
    """
    if check("Episode", nombre):
        return "El Episodio ya existe"
    else:
        engine.execute(f"""INSERT INTO Episode (Name, Number_episode, Season_id_Season) 
                       VALUES ('{nombre}', '{number}', 1);""")

# %%
def insertActors(nombre):
    """
    Llama a la función check para comprobar si existe el Actor
    Inserta actor si no existe
    """
    if check("Actors", nombre):
        return "El Actor ya existe"
    else:
        engine.execute(f"INSERT INTO Actors (Name) VALUES ('{nombre}');")

# %%
def dameId(que,string):
    """
    Devuelve el ID de lo que le pidamos sabiendo que ese elemento EXISTE
    """
    if que == "Season":
        return list(engine.execute(f"SELECT id_Season FROM Season WHERE Number ='{string}';"))[0][0]
    elif que == "Episode":
        return list(engine.execute(f"SELECT id_episode FROM Episode WHERE Name ='{string}';"))[0][0]
    elif que == "Actors":
        return list(engine.execute(f"SELECT id_Actors FROM Actors WHERE Name ='{string}';"))[0][0]

# %%
df3.sample()
# Out:
#                                                 Dialogue    Actor  \
# 37609   Leonard, I assumed you knew. The ranking of r...  Sheldon
#
#                         Name_Episode Number_Series Number_Episode
# 37609  The First Pitch Insufficiency            08             03

# %%
def insertDialogue(fila):
    """
    La función final 
    """
    if check("Dialogue", fila["Dialogue"]):
        return "El dialogo ya existe"
    else:
        if check("Episode", fila["Name_Episode"]):
            episode_id = dameId("Episode", fila["Name_Episode"])
        else:
            insertEpisode(fila["Name_Episode"], fila["Number_Episode"])
            episode_id = dameId("Episode", fila["Name_Episode"])
        
        if check("Actors", fila["Actor"]):
            actors_id = dameId("Actors", fila["Actor"])
        else:
            insertActors(fila["Actor"])
            actors_id = dameId("Actors", fila["Actor"])
    
        engine.execute(f"""
        INSERT INTO Dialogue (Episode_id_episode, Actors_id_Actors, Dialogue) 
        VALUES ("{episode_id}", "{actors_id}", "{fila['Dialogue']}");
        """)

# %%
for index, fila in df3.iterrows():
    insertDialogue(fila)
    
#Me ha cargardo los datos antes de darme el error, por lo que la bbdd ya tiene datos para trabajar.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-61cbb9131794> in <module>
#       1 for index, fila in df3.iterrows():
# ----> 2     insertDialogue(fila)
#
# <ipython-input-93-b562d3f51710> in insertDialogue(fila)
#       3     La función final
#       4     """
# ----> 5     if check("Dialogue", fila["Dialogue"]):
#       6         return "El dialogo ya existe"
#       7     else:
#
# <ipython-input-90-457ddc3bd942> in check(que, string)
#      26
#      27     elif que == "Dialogue":
# ---> 28         query = list(engine.execute(f"SELECT Dialogue FROM Dialogue WHERE Dialogue = '{string}'"))
#      29         if len(query) > 0:
#      30             return True
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ...

# %%
# como borrar datos cargados en SQL
SET SQL_SAFE_UPDATES = 0;
DELETE FROM Actors;
